# %% [markdown]
# <a href="https://colab.research.google.com/github/porcelainruler/Kaggle/blob/main/EsteeHackathonOnlyRandomForest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

import pandas as pd
import numpy as np
import seaborn as sbs

import matplotlib.pyplot as plt
import matplotlib

# %matplotlib inline
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# For normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Sklearn Feature Extraction Functions
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import mutual_info_regression, f_regression

# Model Import
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor

import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle/EsteeHackathon"

#changing the working directory
# %cd /content/gdrive/My Drive/Kaggle/EsteeHackathon

# !ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/Kaggle/EsteeHackathon
# kaggle.json
# SampleSubmission.csv
# submission_EsteeHackathon_172_LR_RFR.csv
# submission_EsteeHackathon_172_RFR.csv
# submission_EsteeHackathon_30MI_XG_RFR.csv
# submission_EsteeHackathon_30RFR.csv
# submission_EsteeHackathon_40RFR.csv
# submission_EsteeHackathon_40RFR.gsheet
# submission_EsteeHackathon_56-30F-30MI_AllData_RFR.csv
# submission_EsteeHackathon_56-30MI-30F_RFR_MLP.csv
# submission_EsteeHackathon_89-50F-50MI_AllData_LR_RFR.csv
# submission_EsteeHackathon_89-50MI-50F_AllData_RFR_MLP.csv
# submission_EsteeHackathon_AllFeat_AllData_LR_RFR.csv
# submission_EsteeHackathon_AllFeat_AllDataNORM_LR_RFR.csv
# submission_EsteeHackathon_AllFeat_AllDataNORM_WeightAvg_1_5_LR_RFR.csv
# submission_EsteeHackathon_AllFeat_AllDataNORM_WeightAvg_1_6_LR_RFR.csv
# submission_EsteeHackathon_ALL_LR_RFR.csv
# submission_EsteeHackathon_ALL_RFR.csv
# submission_EsteeHackathon_ALLRFR.csv
# submission_EsteeHackathon.csv
# ...

# %%
other = pd.read_csv('TrainingData.csv.zip')
train = pd.read_csv('X_TRAIN_PF.csv')
test = pd.read_csv('TEST_PF.csv')
# train.head()

train.head()
# Out:
#          A_1       A_2       A_3  ...   B_121.4   B_122.4   B_123.4
# 0   7.523511 -5.010658  0.211973  ... -0.700819 -0.504035 -0.714535
# 1   0.000000 -1.369279 -0.133492  ... -0.019026 -0.186815 -0.126541
# 2   7.523511 -5.010658  0.211973  ... -0.700819 -0.504035 -0.714535
# 3   0.000000 -1.369279 -0.133492  ... -0.019026 -0.186815 -0.126541
# 4  12.517211 -9.673301 -0.004008  ...  2.813197  2.162318  1.958971
#
# [5 rows x 1255 columns]

# %%
X_train_fs = train
y_train = other['Return']

X_test_fs = train.values[len(X_train_fs)-10000:]
y_test = y_train.values[len(X_train_fs)-10000:]

'''
y_arr = Y.to_list()
add_x = []
for i in range(60,len(Y)):
    add_x.append(Y[i-60:i])

add_x = np.array(add_x)

add_x
'''

# Normalize values
from sklearn.preprocessing import Normalizer
import pandas
import numpy

'''
# Normalize Input Features / Values
scaler = Normalizer().fit(X)

X_train_fs = scaler.transform(X_train_fs)
X_test_fs = scaler.transform(X_test_fs)
test_fs = scaler.transform(test)
'''
# Out:
# '\n# Normalize Input Features / Values\nscaler = Normalizer().fit(X)\n\nX_train_fs = scaler.transform(X_train_fs)\nX_test_fs = scaler.transform(X_test_fs)\ntest_fs = scaler.transform(test)\n'

# %%
# Random Forest - Best Result (20 Features Selected By Mutual Info Method - , 40 Features Selected By Mutual Info Method - )

model_RFR = RandomForestRegressor(n_estimators=500)
model_RFR.fit(X_train_fs,y_train)

# Get the mean absolute error on the validation data
predicted_prices = model_RFR.predict(X_test_fs)
# predicted_prices = target_scaler.inverse_transform(predicted_prices)

MAE = mean_absolute_error(y_test , predicted_prices)

rms=np.sqrt(np.mean(np.power((np.array(y_test)-np.array(predicted_prices)),2)))
print('Root Mean Squared Error in Random Forest Regressor:\t', rms)

print('Random forest validation MAE = ', MAE)

# %%
y_pred_RF = model_RFR.predict(test)
# y_pred_RF = target_scaler.inverse_transform(y_pred_RF)

print(y_pred_RF)
